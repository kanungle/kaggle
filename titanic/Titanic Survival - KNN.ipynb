# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
drop_cols = ["Ticket","PassengerId","Cabin","Name","Embarked"]

train_df = train.drop(drop_cols,axis=1)
train_df = train_df.dropna()

test_df = test.drop(drop_cols,axis=1)
test_df = pd.concat([test_df,test["PassengerId"]],axis=1)
test_df = test_df.dropna()

train_df['Sex'] = train_df['Sex'].replace({"male":1,"female":0})
test_df['Sex'] = test_df['Sex'].replace({"male":1,"female":0})

test_df
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  PassengerId
# 0         3    1  34.5      0      0    7.8292          892
# 1         3    0  47.0      1      0    7.0000          893
# 2         2    1  62.0      0      0    9.6875          894
# 3         3    1  27.0      0      0    8.6625          895
# 4         3    0  22.0      1      1   12.2875          896
# ..      ...  ...   ...    ...    ...       ...          ...
# 409       3    0   3.0      1      1   13.7750         1301
# 411       1    0  37.0      1      0   90.0000         1303
# 412       3    0  28.0      0      0    7.7750         1304
# 414       1    0  39.0      0      0  108.9000         1306
# 415       3    1  38.5      0      0    7.2500         1307
#
# [331 rows x 7 columns]

# %%
target = train_df["Survived"]
predictors = train_df.drop(columns="Survived",axis=1)

model = KNeighborsClassifier(n_neighbors=1)
model.fit(predictors,target)

print(model.score(predictors,target))

test_df_anon = test_df.drop("PassengerId",axis=1)
survived = model.predict(test_df_anon)
survived = pd.DataFrame(survived,columns=["Survived"])
result = pd.merge(test_df, survived, left_index=True, right_index=True)

result
# Out:
# 0.9845938375350141
#      Pclass  Sex   Age  SibSp  Parch     Fare  PassengerId  Survived
# 0         3    1  34.5      0      0   7.8292          892         0
# 1         3    0  47.0      1      0   7.0000          893         0
# 2         2    1  62.0      0      0   9.6875          894         1
# 3         3    1  27.0      0      0   8.6625          895         1
# 4         3    0  22.0      1      1  12.2875          896         0
# ..      ...  ...   ...    ...    ...      ...          ...       ...
# 326       2    0  12.0      2      1  39.0000         1218         1
# 327       1    1  46.0      0      0  79.2000         1219         1
# 328       2    1  29.0      1      0  26.0000         1220         0
# 329       2    1  21.0      0      0  13.0000         1221         1
# 330       2    0  48.0      0      2  36.7500         1222         0
#
# [260 rows x 8 columns]
