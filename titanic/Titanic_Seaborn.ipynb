# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt1 = sns.boxplot(data=df,x='Sex',y='Age')
plt1.set_title("Age Distribution by Gender")
# Out:
# Text(0.5, 1.0, 'Age Distribution by Gender')

# %%
men = df[df['Sex']=='male']['Age']
women = df[df['Sex']=='female']['Age']

sns.kdeplot(men,shade=True)
sns.kdeplot(women,shade=True)
plt.legend(labels=['men','women'])

# %%
sns.pairplot(df)

# %%
sns.violinplot(data=df, x='Sex',y='Age')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Last','First']]=df['Name'].str.split(", ",expand=True)
df['Title']= df['First'].str.split(". ",expand=True)[0]
df['Title']
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Title, Length: 891, dtype: object

# %%
f, ax = plt.subplots(figsize=(12,7))
sns.violinplot(data=df,x='Title',y='Age')
# Out:
# <AxesSubplot:xlabel='Title', ylabel='Age'>

# %%
sns.violinplot(data=df, x='Pclass',y='Survived')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>
